# %% [markdown]
# print cmd.get_fastastr('resn DA+DT+DC+DG+TO3+TO5')

# %% [markdown]
# <h1 style="font-size:60px">Sequence of the Nanodisc with the Zi4F-positive Modified Peptide</h1>

# %% [markdown]
# Zi4f-Positive-one_seq:
# TTTTTCACACTTTTTCACACTTTTTTCACACTTTTTCACACTTTTTTCACACTTTTTCACACTTTTTTCA
# CACTTTTTCACACTTTTTTCACACTTTTTCACACTTTTTTCACACTTTTTCACACTTTTTTCACACTTTT
# TCACACT

# %%
import re

one_chain_seq_pos_DNA = """TTTTTCACACTTTTTCACACTTTTTTCACACTTTTTCACACTTTTTTCACACTTTTTCACACTTTTTTCACACTTTTTCACACTTTTTTCACACTTTTTCACACTTTTTTCACACTTTTTCACACTTTTTTCACACTTTTTCACACT"""

print(f"Length of one_chain_seq_pos_DNA: {len(one_chain_seq_pos_DNA[0])} bases")


# --- Define pattern ---
pattern = "TTTTTCACACTTTTTCACACT"

# --- Find all matches (including overlapping ones) ---
matches = [m.start() for m in re.finditer(f"(?={pattern})", one_chain_seq_pos_DNA)]

print(f"Pattern '{pattern}' found {len(matches)} time(s).")
print("Positions:", matches)
# Out:
# Length of one_chain_seq_pos_DNA: 1 bases
# Pattern 'TTTTTCACACTTTTTCACACT' found 7 time(s).
# Positions: [0, 21, 42, 63, 84, 105, 126]

# %% [markdown]
# Start + 1
#
# End stays the same (because End is exclusive in Python)

# %%
import re

text ="""TTTTTCACACTTTTTCACACTTTTTTCACACTTTTTCACACTTTTTTCACACTTTTTCACACTTTTTTCACACTTTTTCACACTTTTTTCACACTTTTTCACACTTTTTTCACACTTTTTCACACTTTTTTCACACTTTTTCACACT"""
pattern =  "TTTTTCACACTTTTTCACACT"

# Using re.finditer()
matches = re.finditer(pattern, text)

for match in matches:
    print(f"Match: '{match.group()}', Start: {match.start()}, End: {match.end()}")
# Out:
# Match: 'TTTTTCACACTTTTTCACACT', Start: 0, End: 21
# Match: 'TTTTTCACACTTTTTCACACT', Start: 21, End: 42
# Match: 'TTTTTCACACTTTTTCACACT', Start: 42, End: 63
# Match: 'TTTTTCACACTTTTTCACACT', Start: 63, End: 84
# Match: 'TTTTTCACACTTTTTCACACT', Start: 84, End: 105
# Match: 'TTTTTCACACTTTTTCACACT', Start: 105, End: 126
# Match: 'TTTTTCACACTTTTTCACACT', Start: 126, End: 147

# %% [markdown]
# ### Complete FASTA Format for the Zi4F-positive Nanodisc Sequence
# TDWFKAFYDKVAEKFKEAFGTTTTCACACTTTTTCACACTDWFKAFYDKVAEKFKEAFGTDWFKAFYDKV
# AEKFKEAFGTTTTCACACTTTTTCACACTDWFKAFYDKVAEKFKEAFGTDWFKAFYDKVAEKFKEAFGTT
# TTCACACTTTTTCACACTDWFKAFYDKVAEKFKEAFGTDWFKAFYDKVAEKFKEAFGTTTTCACACTTTT
# TCACACTDWFKAFYDKVAEKFKEAFGTDWFKAFYDKVAEKFKEAFGTTTTCACACTTTTTCACACTDWFK
# AFYDKVAEKFKEAFGTDWFKAFYDKVAEKFKEAFGTTTTCACACTTTTTCACACTDWFKAFYDKVAEKFK
# EAFGTDWFKAFYDKVAEKFKEAFGTTTTCACACTTTTTCACACTDWFKAFYDKVAEKFKEAFGAGTGTGA
# AAAAGTGTGAAAAAAGTGTGAAAAAGTGTGAAAAAAGTGTGAAAAAGTGTGAAAAAAGTGTGAAAAAGTG
# TGAAAAAAGTGTGAAAAAGTGTGAAAAAAGTGTGAAAAAGTGTGAAAAAAGTGTGAAAAAGTGTGAAAAA
#
# results for 19 residue sequence:
# AspTrpPheLysAlaPheTyrAspLysValAlaGluLysPheLysGluAlaPheGly

# %% [markdown]
# <h1 style="font-size:60px">Sequence of the Nanodisc with the Negatively Modified Peptide</h1>

# %% [markdown]
# Negative:TTTTTCACACTTTTTCACACTTTTTTCACACTTTTTCACACTTTTTTCACACTTTTTCACACTTTTTTCA
# CACTTTTTCACACTTTTTTCACACTTTTTCACACTTTTTTCACACTTTTTCACACTTTTTTCACACTTTT
# TCACACT

# %%
import re
text ="""TTTTTCACACTTTTTCACACTTTTTTCACACTTTTTCACACTTTTTTCACACTTTTTCACACTTTTTTCACACTTTTTCACACTTTTTTCACACTTTTTCACACTTTTTTCACACTTTTTCACACTTTTTTCACACTTTTTCACACT"""
pattern =  "TTTTTCACACTTTTTCACACT"

# Using re.finditer()
matches = re.finditer(pattern, text)

for match in matches:
    print(f"Match: '{match.group()}', Start: {match.start()}, End: {match.end()}")
# Out:
# Match: 'TTTTTCACACTTTTTCACACT', Start: 0, End: 21
# Match: 'TTTTTCACACTTTTTCACACT', Start: 21, End: 42
# Match: 'TTTTTCACACTTTTTCACACT', Start: 42, End: 63
# Match: 'TTTTTCACACTTTTTCACACT', Start: 63, End: 84
# Match: 'TTTTTCACACTTTTTCACACT', Start: 84, End: 105
# Match: 'TTTTTCACACTTTTTCACACT', Start: 105, End: 126
# Match: 'TTTTTCACACTTTTTCACACT', Start: 126, End: 147

# %% [markdown]
# ### Complete FASTA Format for the Negative Nanodisc Sequence
# ...
#
# results for 19 residue sequence:
# AspTrpPheGlnAlaPheTyrAspGlnValAlaGluGlnPheGlnGluAlaPheGly
